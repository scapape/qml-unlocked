# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import pennylane as qml

# Load the dataset
df = pd.read_csv('yourdataset.csv')

# Separate X and y, dropping non-useful columns
X = df.drop(['target'], axis="columns")
y = df['target']

# Split train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# Normalize features
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Autoencoder definition
class Autoencoder(nn.Module):
    def __init__(self, input_dim, latent_dim):
        super(Autoencoder, self).__init__()
        # Encoder
        self.encoder = nn.Sequential(
            nn.Linear(input_dim, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, latent_dim)
        )
        # Decoder
        self.decoder = nn.Sequential(
            nn.Linear(latent_dim, 64),
            nn.ReLU(),
            nn.Linear(64, 128),
            nn.ReLU(),
            nn.Linear(128, input_dim)
        )

    def forward(self, x):
        z = self.encoder(x)
        x_reconstructed = self.decoder(z)
        return z, x_reconstructed

# Quantum circuit definition
n_qubits = 2
latent_dim = 2  
n_layers = 3 # Number of layers in the variational ansatz

def quantum_circuit(params, features):
    qml.AngleEmbedding(features, wires=range(n_qubits), rotation='Y')
    for layer in range(n_layers):
        for i in range(n_qubits):
            qml.RY(params[layer, i], wires=i)
        for i in range(n_qubits - 1):
            qml.CNOT(wires=[i, i + 1])
        qml.CNOT(wires=[n_qubits - 1, 0])
    return qml.expval(qml.PauliZ(0))

# Quantum node and hybrid model
dev = qml.device("default.qubit", wires=n_qubits)

@qml.qnode(dev, interface='torch')
def quantum_node(features, params):
    return quantum_circuit(params, features)

class VQC(nn.Module):
    def __init__(self, latent_dim, n_qubits, n_layers):
        super(VQC, self).__init__()
        self.latent_dim = latent_dim
        self.n_qubits = n_qubits
        self.n_layers = n_layers
        self.params = nn.Parameter(torch.randn(n_layers, n_qubits, dtype=torch.float64))
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x_split = torch.chunk(x, chunks=self.latent_dim // self.n_qubits, dim=1)
        outputs = []
        for x_sub in x_split:
            outputs.append(quantum_node(x_sub, self.params))
        raw_output = torch.stack(outputs, dim=1).mean(dim=1, keepdim=True)
        return self.sigmoid(raw_output)  # Apply sigmoid to constrain output between 0 and 1

# Combined loss function
class GuidedQuantumCompression(nn.Module):
    def __init__(self, autoencoder, vqc, lambda_param):
        super(GuidedQuantumCompression, self).__init__()
        self.autoencoder = autoencoder
        self.vqc = vqc
        self.lambda_param = lambda_param
        self.mse_loss = nn.MSELoss()
        self.bce_loss = nn.BCELoss()

    def forward(self, x, y):
        z, x_reconstructed = self.autoencoder(x)
        y_pred = self.vqc(z)
        reconstruction_loss = self.mse_loss(x_reconstructed, x)
        classification_loss = self.bce_loss(y_pred, y)
        return (1 - self.lambda_param) * reconstruction_loss + self.lambda_param * classification_loss

# Model initialization
input_dim = X_train.shape[1]
lambda_param = 0.5

autoencoder = Autoencoder(input_dim, latent_dim).double()
vqc = VQC(latent_dim, n_qubits, n_layers).double()
model = GuidedQuantumCompression(autoencoder, vqc, lambda_param).double()

# Optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# Training loop
n_epochs = 100
batch_size = 32
X_train_tensor = torch.tensor(X_train, dtype=torch.float64)
y_train_tensor = torch.tensor(y_train.values, dtype=torch.float64).view(-1, 1)

data_loader = torch.utils.data.DataLoader(
    dataset=torch.utils.data.TensorDataset(X_train_tensor, y_train_tensor),
    batch_size=batch_size,
    shuffle=True
)

loss_history = []
for epoch in range(n_epochs):
    total_loss = 0
    reconstruction_loss = 0
    classification_loss = 0
    for batch_x, batch_y in data_loader:
        optimizer.zero_grad()
        z, x_reconstructed = autoencoder(batch_x)
        y_pred = vqc(z)

        # Fix: Use MSELoss directly instead of referring to the autoencoder
        recon_loss = nn.MSELoss()(x_reconstructed, batch_x)
        class_loss = model.bce_loss(y_pred, batch_y)
        loss = (1 - lambda_param) * recon_loss + lambda_param * class_loss

        loss.backward()
        optimizer.step()

        total_loss += loss.item()
        reconstruction_loss += recon_loss.item()
        classification_loss += class_loss.item()
    loss_history.append(total_loss)
    print(f"Epoch {epoch + 1}/{n_epochs}, Total Loss: {total_loss:.4f}, "
          f"Reconstruction Loss: {reconstruction_loss:.4f}, Classification Loss: {classification_loss:.4f}")

# Plot training loss
plt.plot(range(1, n_epochs + 1), loss_history, marker='o')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss Over Epochs')
plt.grid()
plt.show()

# Evaluation
X_test_tensor = torch.tensor(X_test, dtype=torch.float64)
y_test_tensor = torch.tensor(y_test.values, dtype=torch.float64).view(-1, 1)
z_test, _ = autoencoder(X_test_tensor)
preds = vqc(z_test)
preds_probs = preds.detach().numpy()
preds_binary = (preds_probs > 0.5).astype(float)

accuracy = (preds_binary == y_test_tensor.numpy()).mean()
auc_score = roc_auc_score(y_test_tensor.numpy(), preds_probs)

print(f"Test Accuracy: {accuracy:.4f}")
print(f"Test AUC: {auc_score:.4f}")

# Compute KS (Kolmogorov-Smirnov) metric
fpr, tpr, thresholds = roc_curve(y_test_tensor.numpy(), preds_probs)
ks_statistic = np.max(np.abs(fpr - tpr))
print(f"Test KS Statistic: {ks_statistic:.4f}")
# Out:
# Epoch 1/100, Total Loss: 5.7919, Reconstruction Loss: 2.2359, Classification Loss: 9.3480
# Epoch 2/100, Total Loss: 4.5224, Reconstruction Loss: 0.6209, Classification Loss: 8.4239
# Epoch 3/100, Total Loss: 4.2242, Reconstruction Loss: 0.4235, Classification Loss: 8.0248
# Epoch 4/100, Total Loss: 4.1478, Reconstruction Loss: 0.3867, Classification Loss: 7.9090
# Epoch 5/100, Total Loss: 4.0296, Reconstruction Loss: 0.3818, Classification Loss: 7.6775
# Epoch 6/100, Total Loss: 3.9135, Reconstruction Loss: 0.3602, Classification Loss: 7.4668
# Epoch 7/100, Total Loss: 3.7333, Reconstruction Loss: 0.3357, Classification Loss: 7.1309
# Epoch 8/100, Total Loss: 3.5307, Reconstruction Loss: 0.3044, Classification Loss: 6.7570
# Epoch 9/100, Total Loss: 3.3754, Reconstruction Loss: 0.2912, Classification Loss: 6.4597
# Epoch 10/100, Total Loss: 3.2871, Reconstruction Loss: 0.2767, Classification Loss: 6.2976
# Epoch 11/100, Total Loss: 3.1822, Reconstruction Loss: 0.2772, Classification Loss: 6.0871
# Epoch 12/100, Total Loss: 3.1139, Reconstruction Loss: 0.2776, Classification Loss: 5.9502
# Epoch 13/100, Total Loss: 3.0737, Reconstruction Loss: 0.2770, Classification Loss: 5.8703
# Epoch 14/100, Total Loss: 3.0193, Reconstruction Loss: 0.2814, Classification Loss: 5.7571
# Epoch 15/100, Total Loss: 2.9756, Reconstruction Loss: 0.2766, Classification Loss: 5.6745
# Epoch 16/100, Total Loss: 2.9484, Reconstruction Loss: 0.2769, Classification Loss: 5.6198
# Epoch 17/100, Total Loss: 2.9049, Reconstruction Loss: 0.2772, Classification Loss: 5.5326
# Epoch 18/100, Total Loss: 2.8687, Reconstruction Loss: 0.2833, Classification Loss: 5.4541
# Epoch 19/100, Total Loss: 2.8380, Reconstruction Loss: 0.2769, Classification Loss: 5.3992
# Epoch 20/100, Total Loss: 2.8365, Reconstruction Loss: 0.2755, Classification Loss: 5.3974
# Epoch 21/100, Total Loss: 2.8064, Reconstruction Loss: 0.2797, Classification Loss: 5.3330
# Epoch 22/100, Total Loss: 2.7758, Reconstruction Loss: 0.2863, Classification Loss: 5.2654
# Epoch 23/100, Total Loss: 2.7431, Reconstruction Loss: 0.2820, Classification Loss: 5.2042
# Epoch 24/100, Total Loss: 2.7137, Reconstruction Loss: 0.2744, Classification Loss: 5.1531
# Epoch 25/100, Total Loss: 2.6857, Reconstruction Loss: 0.2732, Classification Loss: 5.0981
# Epoch 26/100, Total Loss: 2.6695, Reconstruction Loss: 0.2715, Classification Loss: 5.0675
# Epoch 27/100, Total Loss: 2.6654, Reconstruction Loss: 0.2737, Classification Loss: 5.0571
# Epoch 28/100, Total Loss: 2.6477, Reconstruction Loss: 0.2690, Classification Loss: 5.0264
# Epoch 29/100, Total Loss: 2.6313, Reconstruction Loss: 0.2727, Classification Loss: 4.9899
# Epoch 30/100, Total Loss: 2.6216, Reconstruction Loss: 0.2724, Classification Loss: 4.9707
# Epoch 31/100, Total Loss: 2.6165, Reconstruction Loss: 0.2711, Classification Loss: 4.9618
# Epoch 32/100, Total Loss: 2.6304, Reconstruction Loss: 0.2694, Classification Loss: 4.9914
# Epoch 33/100, Total Loss: 2.6012, Reconstruction Loss: 0.2761, Classification Loss: 4.9264
# Epoch 34/100, Total Loss: 2.5998, Reconstruction Loss: 0.2768, Classification Loss: 4.9228
# Epoch 35/100, Total Loss: 2.5887, Reconstruction Loss: 0.2660, Classification Loss: 4.9114
# Epoch 36/100, Total Loss: 2.5784, Reconstruction Loss: 0.2622, Classification Loss: 4.8945
# Epoch 37/100, Total Loss: 2.5642, Reconstruction Loss: 0.2612, Classification Loss: 4.8671
# Epoch 38/100, Total Loss: 2.5715, Reconstruction Loss: 0.2569, Classification Loss: 4.8860
# Epoch 39/100, Total Loss: 2.5279, Reconstruction Loss: 0.2537, Classification Loss: 4.8021
# Epoch 40/100, Total Loss: 2.5243, Reconstruction Loss: 0.2503, Classification Loss: 4.7984
# Epoch 41/100, Total Loss: 2.5312, Reconstruction Loss: 0.2563, Classification Loss: 4.8061
# Epoch 42/100, Total Loss: 2.5216, Reconstruction Loss: 0.2555, Classification Loss: 4.7877
# Epoch 43/100, Total Loss: 2.5133, Reconstruction Loss: 0.2539, Classification Loss: 4.7727
# Epoch 44/100, Total Loss: 2.5052, Reconstruction Loss: 0.2510, Classification Loss: 4.7594
# Epoch 45/100, Total Loss: 2.5400, Reconstruction Loss: 0.2545, Classification Loss: 4.8255
# Epoch 46/100, Total Loss: 2.4809, Reconstruction Loss: 0.2420, Classification Loss: 4.7197
# Epoch 47/100, Total Loss: 2.4999, Reconstruction Loss: 0.2440, Classification Loss: 4.7559
# Epoch 48/100, Total Loss: 2.4816, Reconstruction Loss: 0.2404, Classification Loss: 4.7227
# Epoch 49/100, Total Loss: 2.4773, Reconstruction Loss: 0.2467, Classification Loss: 4.7078
# Epoch 50/100, Total Loss: 2.4725, Reconstruction Loss: 0.2443, Classification Loss: 4.7007
# Epoch 51/100, Total Loss: 2.4686, Reconstruction Loss: 0.2384, Classification Loss: 4.6987
# Epoch 52/100, Total Loss: 2.4388, Reconstruction Loss: 0.2346, Classification Loss: 4.6431
# Epoch 53/100, Total Loss: 2.4440, Reconstruction Loss: 0.2296, Classification Loss: 4.6583
# Epoch 54/100, Total Loss: 2.4430, Reconstruction Loss: 0.2281, Classification Loss: 4.6578
# Epoch 55/100, Total Loss: 2.4924, Reconstruction Loss: 0.2439, Classification Loss: 4.7409
# Epoch 56/100, Total Loss: 2.4218, Reconstruction Loss: 0.2351, Classification Loss: 4.6086
# Epoch 57/100, Total Loss: 2.4446, Reconstruction Loss: 0.2259, Classification Loss: 4.6634
# Epoch 58/100, Total Loss: 2.4818, Reconstruction Loss: 0.2326, Classification Loss: 4.7310
# Epoch 59/100, Total Loss: 2.4319, Reconstruction Loss: 0.2314, Classification Loss: 4.6323
# Epoch 60/100, Total Loss: 2.4030, Reconstruction Loss: 0.2278, Classification Loss: 4.5782
# Epoch 61/100, Total Loss: 2.3973, Reconstruction Loss: 0.2200, Classification Loss: 4.5746
# Epoch 62/100, Total Loss: 2.4046, Reconstruction Loss: 0.2198, Classification Loss: 4.5895
# Epoch 63/100, Total Loss: 2.3964, Reconstruction Loss: 0.2179, Classification Loss: 4.5750
# Epoch 64/100, Total Loss: 2.3793, Reconstruction Loss: 0.2198, Classification Loss: 4.5389
# Epoch 65/100, Total Loss: 2.3828, Reconstruction Loss: 0.2156, Classification Loss: 4.5500
# Epoch 66/100, Total Loss: 2.3847, Reconstruction Loss: 0.2221, Classification Loss: 4.5474
# Epoch 67/100, Total Loss: 2.3759, Reconstruction Loss: 0.2213, Classification Loss: 4.5305
# Epoch 68/100, Total Loss: 2.3562, Reconstruction Loss: 0.2159, Classification Loss: 4.4965
# Epoch 69/100, Total Loss: 2.3701, Reconstruction Loss: 0.2174, Classification Loss: 4.5227
# Epoch 70/100, Total Loss: 2.3693, Reconstruction Loss: 0.2153, Classification Loss: 4.5233
# Epoch 71/100, Total Loss: 2.3662, Reconstruction Loss: 0.2161, Classification Loss: 4.5162
# Epoch 72/100, Total Loss: 2.3704, Reconstruction Loss: 0.2155, Classification Loss: 4.5254
# Epoch 73/100, Total Loss: 2.3608, Reconstruction Loss: 0.2155, Classification Loss: 4.5060
# Epoch 74/100, Total Loss: 2.3629, Reconstruction Loss: 0.2170, Classification Loss: 4.5087
# Epoch 75/100, Total Loss: 2.3734, Reconstruction Loss: 0.2219, Classification Loss: 4.5248
# Epoch 76/100, Total Loss: 2.3464, Reconstruction Loss: 0.2224, Classification Loss: 4.4705
# Epoch 77/100, Total Loss: 2.3428, Reconstruction Loss: 0.2219, Classification Loss: 4.4637
# Epoch 78/100, Total Loss: 2.3377, Reconstruction Loss: 0.2174, Classification Loss: 4.4580
# Epoch 79/100, Total Loss: 2.3438, Reconstruction Loss: 0.2169, Classification Loss: 4.4706
# Epoch 80/100, Total Loss: 2.3344, Reconstruction Loss: 0.2171, Classification Loss: 4.4518
# Epoch 81/100, Total Loss: 2.3390, Reconstruction Loss: 0.2149, Classification Loss: 4.4630
# Epoch 82/100, Total Loss: 2.3358, Reconstruction Loss: 0.2209, Classification Loss: 4.4507
# Epoch 83/100, Total Loss: 2.3263, Reconstruction Loss: 0.2200, Classification Loss: 4.4326
# Epoch 84/100, Total Loss: 2.3200, Reconstruction Loss: 0.2165, Classification Loss: 4.4235
# Epoch 85/100, Total Loss: 2.3265, Reconstruction Loss: 0.2197, Classification Loss: 4.4334
# Epoch 86/100, Total Loss: 2.3380, Reconstruction Loss: 0.2218, Classification Loss: 4.4543
# Epoch 87/100, Total Loss: 2.3227, Reconstruction Loss: 0.2208, Classification Loss: 4.4247
# Epoch 88/100, Total Loss: 2.3201, Reconstruction Loss: 0.2144, Classification Loss: 4.4257
# Epoch 89/100, Total Loss: 2.3196, Reconstruction Loss: 0.2185, Classification Loss: 4.4207
# Epoch 90/100, Total Loss: 2.3283, Reconstruction Loss: 0.2230, Classification Loss: 4.4336
# Epoch 91/100, Total Loss: 2.3091, Reconstruction Loss: 0.2168, Classification Loss: 4.4014
# Epoch 92/100, Total Loss: 2.3340, Reconstruction Loss: 0.2192, Classification Loss: 4.4489
# Epoch 93/100, Total Loss: 2.3515, Reconstruction Loss: 0.2208, Classification Loss: 4.4822
# Epoch 94/100, Total Loss: 2.3427, Reconstruction Loss: 0.2174, Classification Loss: 4.4679
# Epoch 95/100, Total Loss: 2.3138, Reconstruction Loss: 0.2191, Classification Loss: 4.4084
# Epoch 96/100, Total Loss: 2.3190, Reconstruction Loss: 0.2174, Classification Loss: 4.4205
# Epoch 97/100, Total Loss: 2.3036, Reconstruction Loss: 0.2171, Classification Loss: 4.3900
# Epoch 98/100, Total Loss: 2.3160, Reconstruction Loss: 0.2172, Classification Loss: 4.4148
# Epoch 99/100, Total Loss: 2.3010, Reconstruction Loss: 0.2185, Classification Loss: 4.3836
# Epoch 100/100, Total Loss: 2.3109, Reconstruction Loss: 0.2201, Classification Loss: 4.4018
# Test Accuracy: 0.8900
# Test AUC: 0.9114
# Test KS Statistic: 0.7580

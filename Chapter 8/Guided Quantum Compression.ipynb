# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import pennylane as qml

# Load the dataset
df = pd.read_csv('yourdataset.csv')

# Separate X and y, dropping non-useful columns
X = df.drop(['target'], axis="columns")
y = df['target']

# Split train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# Normalize features
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Autoencoder definition
class Autoencoder(nn.Module):
    def __init__(self, input_dim, latent_dim):
        super(Autoencoder, self).__init__()
        # Encoder
        self.encoder = nn.Sequential(
            nn.Linear(input_dim, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, latent_dim)
        )
        # Decoder
        self.decoder = nn.Sequential(
            nn.Linear(latent_dim, 64),
            nn.ReLU(),
            nn.Linear(64, 128),
            nn.ReLU(),
            nn.Linear(128, input_dim)
        )

    def forward(self, x):
        z = self.encoder(x)
        x_reconstructed = self.decoder(z)
        return z, x_reconstructed

# Quantum circuit definition
n_qubits = 2
latent_dim = 2  
n_layers = 3 # Number of layers in the variational ansatz

def quantum_circuit(params, features):
    qml.AngleEmbedding(features, wires=range(n_qubits), rotation='Y')
    for layer in range(n_layers):
        for i in range(n_qubits):
            qml.RY(params[layer, i], wires=i)
        for i in range(n_qubits - 1):
            qml.CNOT(wires=[i, i + 1])
        qml.CNOT(wires=[n_qubits - 1, 0])
    return qml.expval(qml.PauliZ(0))

# Quantum node and hybrid model
dev = qml.device("default.qubit", wires=n_qubits)

@qml.qnode(dev, interface='torch')
def quantum_node(features, params):
    return quantum_circuit(params, features)

class VQC(nn.Module):
    def __init__(self, latent_dim, n_qubits, n_layers):
        super(VQC, self).__init__()
        self.latent_dim = latent_dim
        self.n_qubits = n_qubits
        self.n_layers = n_layers
        self.params = nn.Parameter(torch.randn(n_layers, n_qubits, dtype=torch.float64))
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x_split = torch.chunk(x, chunks=self.latent_dim // self.n_qubits, dim=1)
        outputs = []
        for x_sub in x_split:
            outputs.append(quantum_node(x_sub, self.params))
        raw_output = torch.stack(outputs, dim=1).mean(dim=1, keepdim=True)
        return self.sigmoid(raw_output)  # Apply sigmoid to constrain output between 0 and 1

# Combined loss function
class GuidedQuantumCompression(nn.Module):
    def __init__(self, autoencoder, vqc, lambda_param):
        super(GuidedQuantumCompression, self).__init__()
        self.autoencoder = autoencoder
        self.vqc = vqc
        self.lambda_param = lambda_param
        self.mse_loss = nn.MSELoss()
        self.bce_loss = nn.BCELoss()

    def forward(self, x, y):
        z, x_reconstructed = self.autoencoder(x)
        y_pred = self.vqc(z)
        reconstruction_loss = self.mse_loss(x_reconstructed, x)
        classification_loss = self.bce_loss(y_pred, y)
        return (1 - self.lambda_param) * reconstruction_loss + self.lambda_param * classification_loss

# Model initialization
input_dim = X_train.shape[1]
lambda_param = 0.5

autoencoder = Autoencoder(input_dim, latent_dim).double()
vqc = VQC(latent_dim, n_qubits, n_layers).double()
model = GuidedQuantumCompression(autoencoder, vqc, lambda_param).double()

# Optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# Training loop
n_epochs = 100
batch_size = 32
X_train_tensor = torch.tensor(X_train, dtype=torch.float64)
y_train_tensor = torch.tensor(y_train.values, dtype=torch.float64).view(-1, 1)

data_loader = torch.utils.data.DataLoader(
    dataset=torch.utils.data.TensorDataset(X_train_tensor, y_train_tensor),
    batch_size=batch_size,
    shuffle=True
)

loss_history = []
for epoch in range(n_epochs):
    total_loss = 0
    reconstruction_loss = 0
    classification_loss = 0
    for batch_x, batch_y in data_loader:
        optimizer.zero_grad()
        z, x_reconstructed = autoencoder(batch_x)
        y_pred = vqc(z)

        # Fix: Use MSELoss directly instead of referring to the autoencoder
        recon_loss = nn.MSELoss()(x_reconstructed, batch_x)
        class_loss = model.bce_loss(y_pred, batch_y)
        loss = (1 - lambda_param) * recon_loss + lambda_param * class_loss

        loss.backward()
        optimizer.step()

        total_loss += loss.item()
        reconstruction_loss += recon_loss.item()
        classification_loss += class_loss.item()
    loss_history.append(total_loss)
    print(f"Epoch {epoch + 1}/{n_epochs}, Total Loss: {total_loss:.4f}, "
          f"Reconstruction Loss: {reconstruction_loss:.4f}, Classification Loss: {classification_loss:.4f}")

# Plot training loss
plt.plot(range(1, n_epochs + 1), loss_history, marker='o')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss Over Epochs')
plt.grid()
plt.show()

# Evaluation
X_test_tensor = torch.tensor(X_test, dtype=torch.float64)
y_test_tensor = torch.tensor(y_test.values, dtype=torch.float64).view(-1, 1)
z_test, _ = autoencoder(X_test_tensor)
preds = vqc(z_test)
preds_probs = preds.detach().numpy()
preds_binary = (preds_probs > 0.5).astype(float)

accuracy = (preds_binary == y_test_tensor.numpy()).mean()
auc_score = roc_auc_score(y_test_tensor.numpy(), preds_probs)

print(f"Test Accuracy: {accuracy:.4f}")
print(f"Test AUC: {auc_score:.4f}")

# Compute KS (Kolmogorov-Smirnov) metric
fpr, tpr, thresholds = roc_curve(y_test_tensor.numpy(), preds_probs)
ks_statistic = np.max(np.abs(fpr - tpr))
print(f"Test KS Statistic: {ks_statistic:.4f}")
# Out:
# Epoch 1/100, Total Loss: 5.5314, Reconstruction Loss: 2.8926, Classification Loss: 8.1702
# Epoch 2/100, Total Loss: 4.3291, Reconstruction Loss: 0.8385, Classification Loss: 7.8197
# Epoch 3/100, Total Loss: 4.0544, Reconstruction Loss: 0.4505, Classification Loss: 7.6584
# Epoch 4/100, Total Loss: 3.7894, Reconstruction Loss: 0.3666, Classification Loss: 7.2122
# Epoch 5/100, Total Loss: 3.5245, Reconstruction Loss: 0.3159, Classification Loss: 6.7331
# Epoch 6/100, Total Loss: 3.2823, Reconstruction Loss: 0.2783, Classification Loss: 6.2864
# Epoch 7/100, Total Loss: 3.1675, Reconstruction Loss: 0.2701, Classification Loss: 6.0650
# Epoch 8/100, Total Loss: 3.0590, Reconstruction Loss: 0.2730, Classification Loss: 5.8450
# Epoch 9/100, Total Loss: 2.9953, Reconstruction Loss: 0.2683, Classification Loss: 5.7224
# Epoch 10/100, Total Loss: 2.9818, Reconstruction Loss: 0.2692, Classification Loss: 5.6944
# Epoch 11/100, Total Loss: 2.9203, Reconstruction Loss: 0.2742, Classification Loss: 5.5664
# Epoch 12/100, Total Loss: 2.8985, Reconstruction Loss: 0.2753, Classification Loss: 5.5216
# Epoch 13/100, Total Loss: 2.8186, Reconstruction Loss: 0.2742, Classification Loss: 5.3629
# Epoch 14/100, Total Loss: 2.7903, Reconstruction Loss: 0.2752, Classification Loss: 5.3054
# Epoch 15/100, Total Loss: 2.7774, Reconstruction Loss: 0.2643, Classification Loss: 5.2905
# Epoch 16/100, Total Loss: 2.7419, Reconstruction Loss: 0.2685, Classification Loss: 5.2154
# Epoch 17/100, Total Loss: 2.7165, Reconstruction Loss: 0.2659, Classification Loss: 5.1671
# Epoch 18/100, Total Loss: 2.6994, Reconstruction Loss: 0.2696, Classification Loss: 5.1292
# Epoch 19/100, Total Loss: 2.7148, Reconstruction Loss: 0.2718, Classification Loss: 5.1578
# Epoch 20/100, Total Loss: 2.6856, Reconstruction Loss: 0.2658, Classification Loss: 5.1053
# Epoch 21/100, Total Loss: 2.6954, Reconstruction Loss: 0.2720, Classification Loss: 5.1187
# Epoch 22/100, Total Loss: 2.6436, Reconstruction Loss: 0.2731, Classification Loss: 5.0141
# Epoch 23/100, Total Loss: 2.6448, Reconstruction Loss: 0.2683, Classification Loss: 5.0214
# Epoch 24/100, Total Loss: 2.6185, Reconstruction Loss: 0.2560, Classification Loss: 4.9811
# Epoch 25/100, Total Loss: 2.5991, Reconstruction Loss: 0.2503, Classification Loss: 4.9480
# Epoch 26/100, Total Loss: 2.5808, Reconstruction Loss: 0.2485, Classification Loss: 4.9130
# Epoch 27/100, Total Loss: 2.5656, Reconstruction Loss: 0.2441, Classification Loss: 4.8871
# Epoch 28/100, Total Loss: 2.5491, Reconstruction Loss: 0.2401, Classification Loss: 4.8580
# Epoch 29/100, Total Loss: 2.5553, Reconstruction Loss: 0.2439, Classification Loss: 4.8667
# Epoch 30/100, Total Loss: 2.5831, Reconstruction Loss: 0.2559, Classification Loss: 4.9102
# Epoch 31/100, Total Loss: 2.5562, Reconstruction Loss: 0.2508, Classification Loss: 4.8616
# Epoch 32/100, Total Loss: 2.5158, Reconstruction Loss: 0.2384, Classification Loss: 4.7932
# Epoch 33/100, Total Loss: 2.5372, Reconstruction Loss: 0.2373, Classification Loss: 4.8372
# Epoch 34/100, Total Loss: 2.5220, Reconstruction Loss: 0.2322, Classification Loss: 4.8118
# Epoch 35/100, Total Loss: 2.5028, Reconstruction Loss: 0.2307, Classification Loss: 4.7748
# Epoch 36/100, Total Loss: 2.4950, Reconstruction Loss: 0.2272, Classification Loss: 4.7628
# Epoch 37/100, Total Loss: 2.5097, Reconstruction Loss: 0.2350, Classification Loss: 4.7844
# Epoch 38/100, Total Loss: 2.4917, Reconstruction Loss: 0.2339, Classification Loss: 4.7494
# Epoch 39/100, Total Loss: 2.4751, Reconstruction Loss: 0.2317, Classification Loss: 4.7185
# Epoch 40/100, Total Loss: 2.5043, Reconstruction Loss: 0.2295, Classification Loss: 4.7792
# Epoch 41/100, Total Loss: 2.4631, Reconstruction Loss: 0.2293, Classification Loss: 4.6970
# Epoch 42/100, Total Loss: 2.4638, Reconstruction Loss: 0.2299, Classification Loss: 4.6977
# Epoch 43/100, Total Loss: 2.4877, Reconstruction Loss: 0.2364, Classification Loss: 4.7390
# Epoch 44/100, Total Loss: 2.4688, Reconstruction Loss: 0.2313, Classification Loss: 4.7063
# Epoch 45/100, Total Loss: 2.4523, Reconstruction Loss: 0.2277, Classification Loss: 4.6769
# Epoch 46/100, Total Loss: 2.4470, Reconstruction Loss: 0.2290, Classification Loss: 4.6649
# Epoch 47/100, Total Loss: 2.4475, Reconstruction Loss: 0.2293, Classification Loss: 4.6657
# Epoch 48/100, Total Loss: 2.4506, Reconstruction Loss: 0.2294, Classification Loss: 4.6718
# Epoch 49/100, Total Loss: 2.4490, Reconstruction Loss: 0.2283, Classification Loss: 4.6697
# Epoch 50/100, Total Loss: 2.4250, Reconstruction Loss: 0.2251, Classification Loss: 4.6250
# Epoch 51/100, Total Loss: 2.4322, Reconstruction Loss: 0.2298, Classification Loss: 4.6346
# Epoch 52/100, Total Loss: 2.4161, Reconstruction Loss: 0.2298, Classification Loss: 4.6024
# Epoch 53/100, Total Loss: 2.4845, Reconstruction Loss: 0.2361, Classification Loss: 4.7328
# Epoch 54/100, Total Loss: 2.4289, Reconstruction Loss: 0.2357, Classification Loss: 4.6220
# Epoch 55/100, Total Loss: 2.4343, Reconstruction Loss: 0.2304, Classification Loss: 4.6383
# Epoch 56/100, Total Loss: 2.4120, Reconstruction Loss: 0.2282, Classification Loss: 4.5957
# Epoch 57/100, Total Loss: 2.4371, Reconstruction Loss: 0.2243, Classification Loss: 4.6499
# Epoch 58/100, Total Loss: 2.4265, Reconstruction Loss: 0.2296, Classification Loss: 4.6234
# Epoch 59/100, Total Loss: 2.4097, Reconstruction Loss: 0.2236, Classification Loss: 4.5958
# Epoch 60/100, Total Loss: 2.4019, Reconstruction Loss: 0.2235, Classification Loss: 4.5802
# Epoch 61/100, Total Loss: 2.4057, Reconstruction Loss: 0.2234, Classification Loss: 4.5880
# Epoch 62/100, Total Loss: 2.4207, Reconstruction Loss: 0.2217, Classification Loss: 4.6197
# Epoch 63/100, Total Loss: 2.4124, Reconstruction Loss: 0.2228, Classification Loss: 4.6020
# Epoch 64/100, Total Loss: 2.4066, Reconstruction Loss: 0.2256, Classification Loss: 4.5875
# Epoch 65/100, Total Loss: 2.3820, Reconstruction Loss: 0.2222, Classification Loss: 4.5419
# Epoch 66/100, Total Loss: 2.4255, Reconstruction Loss: 0.2224, Classification Loss: 4.6286
# Epoch 67/100, Total Loss: 2.4200, Reconstruction Loss: 0.2365, Classification Loss: 4.6034
# Epoch 68/100, Total Loss: 2.4403, Reconstruction Loss: 0.2277, Classification Loss: 4.6530
# Epoch 69/100, Total Loss: 2.3887, Reconstruction Loss: 0.2229, Classification Loss: 4.5544
# Epoch 70/100, Total Loss: 2.3921, Reconstruction Loss: 0.2212, Classification Loss: 4.5629
# Epoch 71/100, Total Loss: 2.3954, Reconstruction Loss: 0.2215, Classification Loss: 4.5693
# Epoch 72/100, Total Loss: 2.3839, Reconstruction Loss: 0.2200, Classification Loss: 4.5478
# Epoch 73/100, Total Loss: 2.3644, Reconstruction Loss: 0.2161, Classification Loss: 4.5128
# Epoch 74/100, Total Loss: 2.3688, Reconstruction Loss: 0.2157, Classification Loss: 4.5220
# Epoch 75/100, Total Loss: 2.3779, Reconstruction Loss: 0.2217, Classification Loss: 4.5341
# Epoch 76/100, Total Loss: 2.3720, Reconstruction Loss: 0.2223, Classification Loss: 4.5217
# Epoch 77/100, Total Loss: 2.3649, Reconstruction Loss: 0.2193, Classification Loss: 4.5105
# Epoch 78/100, Total Loss: 2.3632, Reconstruction Loss: 0.2169, Classification Loss: 4.5094
# Epoch 79/100, Total Loss: 2.3696, Reconstruction Loss: 0.2140, Classification Loss: 4.5252
# Epoch 80/100, Total Loss: 2.3561, Reconstruction Loss: 0.2169, Classification Loss: 4.4953
# Epoch 81/100, Total Loss: 2.3629, Reconstruction Loss: 0.2174, Classification Loss: 4.5084
# Epoch 82/100, Total Loss: 2.3580, Reconstruction Loss: 0.2166, Classification Loss: 4.4994
# Epoch 83/100, Total Loss: 2.3476, Reconstruction Loss: 0.2190, Classification Loss: 4.4761
# Epoch 84/100, Total Loss: 2.3522, Reconstruction Loss: 0.2161, Classification Loss: 4.4883
# Epoch 85/100, Total Loss: 2.3645, Reconstruction Loss: 0.2171, Classification Loss: 4.5119
# Epoch 86/100, Total Loss: 2.3666, Reconstruction Loss: 0.2202, Classification Loss: 4.5130
# Epoch 87/100, Total Loss: 2.3492, Reconstruction Loss: 0.2176, Classification Loss: 4.4808
# Epoch 88/100, Total Loss: 2.3525, Reconstruction Loss: 0.2174, Classification Loss: 4.4876
# Epoch 89/100, Total Loss: 2.3658, Reconstruction Loss: 0.2198, Classification Loss: 4.5117
# Epoch 90/100, Total Loss: 2.3384, Reconstruction Loss: 0.2150, Classification Loss: 4.4618
# Epoch 91/100, Total Loss: 2.3318, Reconstruction Loss: 0.2125, Classification Loss: 4.4511
# Epoch 92/100, Total Loss: 2.3611, Reconstruction Loss: 0.2193, Classification Loss: 4.5029
# Epoch 93/100, Total Loss: 2.3380, Reconstruction Loss: 0.2214, Classification Loss: 4.4546
# Epoch 94/100, Total Loss: 2.3298, Reconstruction Loss: 0.2172, Classification Loss: 4.4423
# Epoch 95/100, Total Loss: 2.3575, Reconstruction Loss: 0.2170, Classification Loss: 4.4981
# Epoch 96/100, Total Loss: 2.3277, Reconstruction Loss: 0.2179, Classification Loss: 4.4376
# Epoch 97/100, Total Loss: 2.3681, Reconstruction Loss: 0.2173, Classification Loss: 4.5190
# Epoch 98/100, Total Loss: 2.3283, Reconstruction Loss: 0.2151, Classification Loss: 4.4415
# Epoch 99/100, Total Loss: 2.3156, Reconstruction Loss: 0.2147, Classification Loss: 4.4165
# Epoch 100/100, Total Loss: 2.3237, Reconstruction Loss: 0.2146, Classification Loss: 4.4328
# Test Accuracy: 0.9200
# Test AUC: 0.9231
# Test KS Statistic: 0.7743
